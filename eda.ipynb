# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
nltk.download('stopwords')
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Load tweet_emotions data set.

# %%
df = pd.read_csv("sample_data/tweet_emotions.csv")

# %% [markdown]
# Print data frame.

# %%
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 3 columns]

# %% [markdown]
# Print the first five columns.

# %%
df.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %% [markdown]
# Print all of the columns of the data frame.

# %%
df.columns
# Out:
# Index(['tweet_id', 'sentiment', 'content'], dtype='object')

# %% [markdown]
# Print the number of sentiment words.

# %%
temp = df.groupby('sentiment').count()['content'].reset_index().sort_values(by='content',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_363fe_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_363fe_row1_col1 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_363fe_row2_col1 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_363fe_row3_col1 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_363fe_row4_col1 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_363fe_row5_col1 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_363fe_row6_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_363fe_row7_col1 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_363fe_row8_col1 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_363fe_row9_col1 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_363fe_row10_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_363fe_row11_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_363fe_row12_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_363fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_363fe_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_363fe_level0_col1" class="col_heading level0 col1" >content</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_363fe_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_363fe_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_363fe_row0_col1" class="data row0 col1" >8638</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_363fe_row1_col0" class="data row1 col0" >worry</td>
#       <td id="T_363fe_row1_col1" class="data row1 col1" >8459</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_363fe_row2_col0" class="data row2 col0" >happiness</td>
#       <td id="T_363fe_row2_col1" class="data row2 col1" >5209</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_363fe_row3_col0" class="data row3 col0" >sadness</td>
#       <td id="T_363fe_row3_col1" class="data row3 col1" >5165</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_363fe_row4_col0" class="data row4 col0" >love</td>
#       <td id="T_363fe_row4_col1" class="data row4 col1" >3842</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_363fe_row5_col0" class="data row5 col0" >surprise</td>
#       <td id="T_363fe_row5_col1" class="data row5 col1" >2187</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_363fe_row6_col0" class="data row6 col0" >fun</td>
#       <td id="T_363fe_row6_col1" class="data row6 col1" >1776</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_363fe_row7_col0" class="data row7 col0" >relief</td>
#       <td id="T_363fe_row7_col1" class="data row7 col1" >1526</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_363fe_row8_col0" class="data row8 col0" >hate</td>
#       <td id="T_363fe_row8_col1" class="data row8 col1" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_363fe_row9_col0" class="data row9 col0" >empty</td>
#       <td id="T_363fe_row9_col1" class="data row9 col1" >827</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_363fe_row10_col0" class="data row10 col0" >enthusiasm</td>
#       <td id="T_363fe_row10_col1" class="data row10 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row11" class="row_heading level0 row11" >1</th>
#       <td id="T_363fe_row11_col0" class="data row11 col0" >boredom</td>
#       <td id="T_363fe_row11_col1" class="data row11 col1" >179</td>
#     </tr>
#     <tr>
#       <th id="T_363fe_level0_row12" class="row_heading level0 row12" >0</th>
#       <td id="T_363fe_row12_col0" class="data row12 col0" >anger</td>
#       <td id="T_363fe_row12_col1" class="data row12 col1" >110</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Print data above as a bar graph.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
df['temp_list'] = df['content'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['content','temp_list']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a1d73_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a1d73_row1_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_a1d73_row2_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_a1d73_row3_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_a1d73_row4_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_a1d73_row5_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_a1d73_row6_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_a1d73_row7_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_a1d73_row8_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_a1d73_row9_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_a1d73_row10_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_a1d73_row11_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_a1d73_row12_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_a1d73_row13_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_a1d73_row14_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a1d73_row15_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_a1d73_row16_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a1d73_row17_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_a1d73_row18_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_a1d73_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a1d73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1d73_level0_col0" class="col_heading level0 col0" >content</th>
#       <th id="T_a1d73_level0_col1" class="col_heading level0 col1" >temp_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1d73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1d73_row0_col0" class="data row0 col0" >to</td>
#       <td id="T_a1d73_row0_col1" class="data row0 col1" >14039</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1d73_row1_col0" class="data row1 col0" >I</td>
#       <td id="T_a1d73_row1_col1" class="data row1 col1" >12635</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1d73_row2_col0" class="data row2 col0" >the</td>
#       <td id="T_a1d73_row2_col1" class="data row2 col1" >12052</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1d73_row3_col0" class="data row3 col0" >a</td>
#       <td id="T_a1d73_row3_col1" class="data row3 col1" >9352</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1d73_row4_col0" class="data row4 col0" >my</td>
#       <td id="T_a1d73_row4_col1" class="data row4 col1" >7160</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1d73_row5_col0" class="data row5 col0" >and</td>
#       <td id="T_a1d73_row5_col1" class="data row5 col1" >6750</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1d73_row6_col0" class="data row6 col0" >i</td>
#       <td id="T_a1d73_row6_col1" class="data row6 col1" >6257</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1d73_row7_col0" class="data row7 col0" >you</td>
#       <td id="T_a1d73_row7_col1" class="data row7 col1" >5535</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1d73_row8_col0" class="data row8 col0" >is</td>
#       <td id="T_a1d73_row8_col1" class="data row8 col1" >5254</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1d73_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_a1d73_row9_col1" class="data row9 col1" >5146</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1d73_row10_col0" class="data row10 col0" >in</td>
#       <td id="T_a1d73_row10_col1" class="data row10 col1" >5053</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1d73_row11_col0" class="data row11 col0" >of</td>
#       <td id="T_a1d73_row11_col1" class="data row11 col1" >4419</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1d73_row12_col0" class="data row12 col0" >it</td>
#       <td id="T_a1d73_row12_col1" class="data row12 col1" >4333</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a1d73_row13_col0" class="data row13 col0" >on</td>
#       <td id="T_a1d73_row13_col1" class="data row13 col1" >3828</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a1d73_row14_col0" class="data row14 col0" >have</td>
#       <td id="T_a1d73_row14_col1" class="data row14 col1" >3430</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a1d73_row15_col0" class="data row15 col0" >me</td>
#       <td id="T_a1d73_row15_col1" class="data row15 col1" >3109</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a1d73_row16_col0" class="data row16 col0" >that</td>
#       <td id="T_a1d73_row16_col1" class="data row16 col1" >3063</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a1d73_row17_col0" class="data row17 col0" >so</td>
#       <td id="T_a1d73_row17_col1" class="data row17 col1" >3033</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a1d73_row18_col0" class="data row18 col0" >with</td>
#       <td id="T_a1d73_row18_col1" class="data row18 col1" >2838</td>
#     </tr>
#     <tr>
#       <th id="T_a1d73_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a1d73_row19_col0" class="data row19 col0" >be</td>
#       <td id="T_a1d73_row19_col1" class="data row19 col1" >2776</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Print most common words, ignoring stop words.

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(100))
temp = temp.iloc[1:,:]
temp.columns = ['content','temp_list']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_f3f8d_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f3f8d_row1_col1 {
#   background-color: #684da1;
#   color: #f1f1f1;
# }
# #T_f3f8d_row2_col1 {
#   background-color: #7363ad;
#   color: #f1f1f1;
# }
# #T_f3f8d_row3_col1 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_f3f8d_row4_col1 {
#   background-color: #7970b3;
#   color: #f1f1f1;
# }
# #T_f3f8d_row5_col1 {
#   background-color: #8b87bf;
#   color: #f1f1f1;
# }
# #T_f3f8d_row6_col1 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_f3f8d_row7_col1 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_f3f8d_row8_col1 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_f3f8d_row9_col1 {
#   background-color: #aeacd2;
#   color: #000000;
# }
# #T_f3f8d_row10_col1 {
#   background-color: #b6b6d8;
#   color: #000000;
# }
# #T_f3f8d_row11_col1 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_f3f8d_row12_col1 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_f3f8d_row13_col1, #T_f3f8d_row14_col1 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_f3f8d_row15_col1 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_f3f8d_row16_col1 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_f3f8d_row17_col1 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_f3f8d_row18_col1 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_f3f8d_row19_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f3f8d_row20_col1 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_f3f8d_row21_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_f3f8d_row22_col1 {
#   background-color: #d3d3e8;
#   color: #000000;
# }
# #T_f3f8d_row23_col1 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_f3f8d_row24_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_f3f8d_row25_col1, #T_f3f8d_row26_col1, #T_f3f8d_row27_col1 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_f3f8d_row28_col1, #T_f3f8d_row29_col1 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_f3f8d_row30_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_f3f8d_row31_col1 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_f3f8d_row32_col1, #T_f3f8d_row33_col1 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_f3f8d_row34_col1 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_f3f8d_row35_col1 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_f3f8d_row36_col1, #T_f3f8d_row37_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_f3f8d_row38_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_f3f8d_row39_col1, #T_f3f8d_row40_col1 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_f3f8d_row41_col1 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_f3f8d_row42_col1 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_f3f8d_row43_col1 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_f3f8d_row44_col1, #T_f3f8d_row45_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_f3f8d_row46_col1 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_f3f8d_row47_col1, #T_f3f8d_row48_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_f3f8d_row49_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_f3f8d_row50_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_f3f8d_row51_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_f3f8d_row52_col1, #T_f3f8d_row53_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_f3f8d_row54_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_f3f8d_row55_col1, #T_f3f8d_row56_col1, #T_f3f8d_row57_col1, #T_f3f8d_row58_col1, #T_f3f8d_row59_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_f3f8d_row60_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_f3f8d_row61_col1, #T_f3f8d_row62_col1, #T_f3f8d_row63_col1, #T_f3f8d_row64_col1 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_f3f8d_row65_col1, #T_f3f8d_row66_col1, #T_f3f8d_row67_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_f3f8d_row68_col1, #T_f3f8d_row69_col1, #T_f3f8d_row70_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_f3f8d_row71_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_f3f8d_row72_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_f3f8d_row73_col1, #T_f3f8d_row74_col1, #T_f3f8d_row75_col1, #T_f3f8d_row76_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_f3f8d_row77_col1, #T_f3f8d_row78_col1, #T_f3f8d_row79_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_f3f8d_row80_col1, #T_f3f8d_row81_col1, #T_f3f8d_row82_col1, #T_f3f8d_row83_col1, #T_f3f8d_row84_col1, #T_f3f8d_row85_col1, #T_f3f8d_row86_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_f3f8d_row87_col1, #T_f3f8d_row88_col1, #T_f3f8d_row89_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_f3f8d_row90_col1, #T_f3f8d_row91_col1, #T_f3f8d_row92_col1, #T_f3f8d_row93_col1, #T_f3f8d_row94_col1, #T_f3f8d_row95_col1, #T_f3f8d_row96_col1, #T_f3f8d_row97_col1, #T_f3f8d_row98_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_f3f8d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3f8d_level0_col0" class="col_heading level0 col0" >content</th>
#       <th id="T_f3f8d_level0_col1" class="col_heading level0 col1" >temp_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f8d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f3f8d_row0_col0" class="data row0 col0" >I'm</td>
#       <td id="T_f3f8d_row0_col1" class="data row0 col1" >2440</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f3f8d_row1_col0" class="data row1 col0" >get</td>
#       <td id="T_f3f8d_row1_col1" class="data row1 col1" >1934</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f3f8d_row2_col0" class="data row2 col0" >like</td>
#       <td id="T_f3f8d_row2_col1" class="data row2 col1" >1808</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f3f8d_row3_col0" class="data row3 col0" >day</td>
#       <td id="T_f3f8d_row3_col1" class="data row3 col1" >1737</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f3f8d_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_f3f8d_row4_col1" class="data row4 col1" >1730</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f3f8d_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_f3f8d_row5_col1" class="data row5 col1" >1558</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f3f8d_row6_col0" class="data row6 col0" >good</td>
#       <td id="T_f3f8d_row6_col1" class="data row6 col1" >1505</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_f3f8d_row7_col0" class="data row7 col0" >got</td>
#       <td id="T_f3f8d_row7_col1" class="data row7 col1" >1453</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_f3f8d_row8_col0" class="data row8 col0" >going</td>
#       <td id="T_f3f8d_row8_col1" class="data row8 col1" >1305</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_f3f8d_row9_col0" class="data row9 col0" >love</td>
#       <td id="T_f3f8d_row9_col1" class="data row9 col1" >1252</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_f3f8d_row10_col0" class="data row10 col0" >work</td>
#       <td id="T_f3f8d_row10_col1" class="data row10 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_f3f8d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_f3f8d_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_f3f8d_row11_col1" class="data row11 col1" >1090</td>
#     </tr>
#     <tr>

# %% [markdown]
# Print table just for sentiment 'empty'.

# %%
df[df['sentiment']=='empty']
# Out:
#          tweet_id sentiment  \
# 0      1956967341     empty
# 44     1956978276     empty
# 52     1956979917     empty
# 141    1957000336     empty
# 180    1957007357     empty
# ...           ...       ...
# 39702  1753868848     empty
# 39742  1753870123     empty
# 39749  1753870555     empty
# 39845  1753886183     empty
# 39975  1753904682     empty
#
#                                                  content  \
# 0      @tiffanylue i know  i was listenin to bad habi...
# 44     @creyes middle school and elem. High schools w...
# 52               @djmicdamn hey yu lil fucker i textd yu
# 141    @softtouchme just answered you- never learned ...
# 180        Have a headache  I'm going to bed. Goodnight!
# ...                                                  ...
# 39702  Here we go again, back to work. Happy Mothers ...
# 39742  @PhilippaJane the &quot;no pants&quot; idea co...
# 39749                                  @sloanyxxx Thanks
# 39845                   @xxxRobyn Yeah *fingers crossed*
# 39975    @lexia Or even listen to Susan's green policies
#
#                                                temp_list
# 0      [@tiffanylue, know, listenin, bad, habit, earl...
# 44     [@creyes, middle, school, elem., High, schools...
# 52         [@djmicdamn, hey, yu, lil, fucker, textd, yu]
# 141    [@softtouchme, answered, you-, never, learned,...
# 180       [Have, headache, I'm, going, bed., Goodnight!]
# ...                                                  ...
# 39702  [Here, go, again,, back, work., Happy, Mothers...
# 39742  [@PhilippaJane, &quot;no, pants&quot;, idea, c...
# 39749                               [@sloanyxxx, Thanks]
# 39845              [@xxxRobyn, Yeah, *fingers, crossed*]
# 39975  [@lexia, Or, even, listen, Susan's, green, pol...
#
# [827 rows x 4 columns]
